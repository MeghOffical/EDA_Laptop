# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('cleaned_laptop.csv')

# %%
df
# Out:
#                                                     Img  \
# 0     https://cdn1.smartprix.com/rx-iFWakgnba-w280-h...
# 1     https://cdn1.smartprix.com/rx-iRe7ozJWD-w280-h...
# 2     https://cdn1.smartprix.com/rx-ifsyyr3XR-w280-h...
# 3     https://cdn1.smartprix.com/rx-i1U6ZPPZL-w280-h...
# 4     https://cdn1.smartprix.com/rx-iAwh1cD03-w280-h...
# ...                                                 ...
# 1011  https://cdn1.smartprix.com/rx-iHvI6zlO3-w280-h...
# 1012  https://cdn1.smartprix.com/rx-iXD506gG6-w280-h...
# 1013  https://cdn1.smartprix.com/rx-iltVnkl02-w280-h...
# 1014  https://cdn1.smartprix.com/rx-ipiGdLesZ-w280-h...
# 1015  https://cdn1.smartprix.com/rx-ia1V7Nusr-w280-h...
#
#                                           Name  Price  Rating(out of 5)  \
# 0        Asus Expertbook P1 P1503CVA-S71075WS   56990              4.60
# 1                   Lenovo V15 G4 ‎82C70081GE   34790              4.35
# 2                HP Victus 15-fb3012AX Gaming   67940              4.10
# ...

# %%
# df['Screen_Size(in inches)']=df['Screen_Size(in inches)'].astype(float)
# df['RAM_size']=df['RAM_size'].astype(float)
# df['RAM_technology']=df['RAM_technology'].astype('category')
# df['OS']=df['OS'].astype('category')
# df['GPU_Brand']=df['GPU_Brand'].astype('category')
# df['GPU_VRAM']=df['GPU_VRAM'].astype('category')
# df['GPU_Type']=df['GPU_Type'].astype('category')
# df['Capacity']=df['Capacity'].astype('category')
# df['Storage_Type']=df['Storage_Type'].astype('category')
# df['Generation']=df['Generation'].astype('category')
# df['Brand']=df['Brand'].astype('category')
# df['Family']=df['Family'].astype('category')
# df['Laptop_Brand']=df['Laptop_Brand'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Img                           1016 non-null   object
#  1   Name                          1016 non-null   object
#  2   Price                         1016 non-null   int64
#  3   Rating(out of 5)              1016 non-null   float64
#  4   Specs_Score(out of 100)       1016 non-null   int64
#  5   OS                            1016 non-null   category
#  6   Core                          997 non-null    float64
#  7   Thread                        931 non-null    float64
#  8   Screen_Size(in inches)        1016 non-null   float64
#  9   Screen_Resolution(in pixels)  1015 non-null   object
#  10  Touch_Screen                  1016 non-null   int64
#  11  warranty(in years)            1016 non-null   int64
# ...

# %%
df.to_csv('laptop_data.csv',index=False)
